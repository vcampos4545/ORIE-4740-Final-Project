# %%
import requests
import mysql.connector as conn
from config import aws_db_config

# %%
def get_matches(params):
    response = requests.get("https://www.vivino.com/api/explore/explore", params=params,
        headers= {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0"
        })
        
    
    print(response)
    
    json = response.json()
    
    matches = json["explore_vintage"]["matches"]
    numMatches = json["explore_vintage"]["records_matched"]
    
    return matches, numMatches

# %%
def match_to_db(cnx, cursor, match):
    """
    Assumes that the Database "WineData" and table "WineData" already exist with 
    columns (Id, Name, Price, Rating, NumRatings, Type, Year, )
    """
    wine = match["vintage"]["wine"]
    
    Id = int(match["vintage"]["id"]) #Wine id
    Name = match["vintage"]["name"] #Wine name
    Price = float(match["price"]["amount"]) #Price of bottle
    Rating = float(wine['statistics']["ratings_average"]) #Wine rating
    NumRatings = int(wine['statistics']['ratings_count']) #Number of ratings
    Type = int(wine["type_id"]) #Type of wine (Red, White, Rose)
    try:
        StyleName = wine["style"]["name"]
    except:
        StyleName = "NONE"
    Year = match["vintage"]["year"] #Wine year
    if Year == "N.V.":
        Year = 0
    elif Year == "":
        Year = -1
    else:
        Year = int(Year)
    try:
        Body = wine['style']['body'] #Body
    except:
        Body = -1
    try:
        Acidity = wine['style']['acidity']
    except:
        Acidity = -1
    Vintage = int(wine["vintage_type"])
    Natural = int(wine["is_natural"])
    try:
        Region = wine['region']["name"] #Wine region
        Country = wine['region']["country"]["name"] #Wine country
    except:
        Region = "NONE"
        Country = "NONE"
    Size = int(match["price"]["bottle_type"]['volume_ml']) #size of bottle
    Winery = wine["winery"]["name"] #Winery
    
    query = (
        f'INSERT INTO WineData (Id,Name,Price,Rating,NumRatings,Type,StyleName,Year,Body,Acidity,Vintage,Nat,Region,Country,Size,Winery)'
        f'VALUES ({Id},"{Name}",{Price},{Rating},{NumRatings},{Type},"{StyleName}",{Year},{Body},{Acidity},{Vintage},{Natural},"{Region}","{Country}",{Size},"{Winery}")'
    )
    try:
        cursor.execute(query)
        cnx.commit()
    except:
        print(f'VALUES ({Id},"{Name}",{Price},{Rating},{NumRatings},{Type},"{StyleName}",{Year},{Body},{Acidity},{Vintage},{Natural},"{Region}","{Country}",{Size},"{Winery}")')

# %%
#Database connection
cnx = conn.connect(**aws_db_config)
cursor = cnx.cursor(buffered=True)

# %%
params = {
        "currency_code":"USD",
        "min_rating":"1",
        "order_by":"price",
        "order":"asc",
        "page": 1,
        "price_range_max":"500",
        "price_range_min":"0",
        "wine_type_ids[]":"1"
}

for wine_id in [1,2,4,3]:
    params["wine_type_ids[]"] = str(wine_id)
    params["page"] = 1
    matches, numMatches = get_matches(params)
    
    for i in range(numMatches//25):
        for match in matches:
            match_to_db(cnx, cursor, match)
        print(f'Added page {params["page"]} to database for wine type {wine_id}')
        params["page"] += 1
        matches, numMatches = get_matches(params)
# Out:
# <Response [200]>
# Added page 1 to database for wine type 1
# <Response [200]>
# Added page 2 to database for wine type 1
# <Response [200]>
# Added page 3 to database for wine type 1
# <Response [200]>
# Added page 4 to database for wine type 1
# <Response [200]>
# Added page 5 to database for wine type 1
# <Response [200]>
# Added page 6 to database for wine type 1
# <Response [200]>
# Added page 7 to database for wine type 1
# <Response [200]>
# Added page 8 to database for wine type 1
# <Response [200]>
# Added page 9 to database for wine type 1
# <Response [200]>
# Added page 10 to database for wine type 1
# <Response [200]>
# Added page 11 to database for wine type 1
# <Response [200]>
# Added page 12 to database for wine type 1
# <Response [200]>
# Added page 13 to database for wine type 1
# <Response [200]>
# Added page 14 to database for wine type 1
# <Response [200]>
# Added page 15 to database for wine type 1
# <Response [200]>
# Added page 16 to database for wine type 1
# <Response [200]>
# Added page 17 to database for wine type 1
# <Response [200]>
# Added page 18 to database for wine type 1
# <Response [200]>
# Added page 19 to database for wine type 1
# <Response [200]>
# Added page 20 to database for wine type 1
# <Response [200]>
# Added page 21 to database for wine type 1
# <Response [200]>
# Added page 22 to database for wine type 1
# <Response [200]>
# Added page 23 to database for wine type 1
# <Response [200]>
# Added page 24 to database for wine type 1
# <Response [200]>
# Added page 25 to database for wine type 1
# <Response [200]>
# Added page 26 to database for wine type 1
# <Response [200]>
# Added page 27 to database for wine type 1
# <Response [200]>
# Added page 28 to database for wine type 1
# <Response [200]>
# Added page 29 to database for wine type 1
# <Response [200]>
# Added page 30 to database for wine type 1
# <Response [200]>
# Added page 31 to database for wine type 1
# <Response [200]>
# Added page 32 to database for wine type 1
# <Response [200]>
# Added page 33 to database for wine type 1
# <Response [200]>
# Added page 34 to database for wine type 1
# <Response [200]>
# Added page 35 to database for wine type 1
# <Response [200]>
# Added page 36 to database for wine type 1
# <Response [200]>
# Added page 37 to database for wine type 1
# <Response [200]>
# Added page 38 to database for wine type 1
# <Response [200]>
# Added page 39 to database for wine type 1
# <Response [200]>
# Added page 40 to database for wine type 1
# <Response [200]>
# Added page 41 to database for wine type 1
# <Response [200]>
# Added page 42 to database for wine type 1
# <Response [200]>
# Added page 43 to database for wine type 1
# <Response [200]>
# Added page 44 to database for wine type 1
# <Response [200]>
# Added page 45 to database for wine type 1
# <Response [200]>
# Added page 46 to database for wine type 1
# <Response [200]>
# Added page 47 to database for wine type 1
# <Response [200]>
# Added page 48 to database for wine type 1
# <Response [200]>
# Added page 49 to database for wine type 1
# <Response [200]>
# Added page 50 to database for wine type 1
# <Response [200]>
# Added page 51 to database for wine type 1
# <Response [200]>
# Added page 52 to database for wine type 1
# <Response [200]>
# Added page 53 to database for wine type 1
# <Response [200]>
# Added page 54 to database for wine type 1
# <Response [200]>
# Added page 55 to database for wine type 1
# <Response [200]>
# Added page 56 to database for wine type 1
# <Response [200]>
# Added page 57 to database for wine type 1
# <Response [200]>
# Added page 58 to database for wine type 1
# <Response [200]>
# Added page 59 to database for wine type 1
# <Response [200]>
# Added page 60 to database for wine type 1
# <Response [200]>
# Added page 61 to database for wine type 1
# <Response [200]>
# Added page 62 to database for wine type 1
# <Response [200]>
# Added page 63 to database for wine type 1
# <Response [200]>
# Added page 64 to database for wine type 1
# <Response [200]>
# Added page 65 to database for wine type 1
# <Response [200]>
# Added page 66 to database for wine type 1
# <Response [200]>
# Added page 67 to database for wine type 1
# <Response [200]>
# Added page 68 to database for wine type 1
# <Response [200]>
# Added page 69 to database for wine type 1
# <Response [200]>
# Added page 70 to database for wine type 1
# <Response [200]>
# Added page 71 to database for wine type 1
# <Response [200]>
# Added page 72 to database for wine type 1
# <Response [200]>
# Added page 73 to database for wine type 1
# <Response [200]>
# Added page 74 to database for wine type 1
# <Response [200]>
# Added page 75 to database for wine type 1
# <Response [200]>
# Added page 76 to database for wine type 1
# <Response [200]>
# Added page 77 to database for wine type 1
# <Response [200]>
# Added page 78 to database for wine type 1
# <Response [200]>
# Added page 79 to database for wine type 1
# <Response [200]>
# Added page 80 to database for wine type 1
# <Response [200]>
# Added page 81 to database for wine type 1
# <Response [200]>
# Added page 82 to database for wine type 1
# <Response [200]>
# Added page 83 to database for wine type 1
# <Response [200]>
# Added page 84 to database for wine type 1
# <Response [200]>
# Added page 85 to database for wine type 1
# <Response [200]>
# Added page 86 to database for wine type 1
# <Response [200]>
# Added page 87 to database for wine type 1
# <Response [200]>
# Added page 88 to database for wine type 1
# <Response [200]>
# Added page 89 to database for wine type 1
# <Response [200]>
# Added page 90 to database for wine type 1
# <Response [200]>
# Added page 91 to database for wine type 1
# <Response [200]>
# Added page 92 to database for wine type 1
# <Response [200]>
# Added page 93 to database for wine type 1
# <Response [200]>
# Added page 94 to database for wine type 1
# <Response [200]>
# Added page 95 to database for wine type 1
# <Response [200]>
# Added page 96 to database for wine type 1
# <Response [200]>
# Added page 97 to database for wine type 1
# <Response [200]>
# Added page 98 to database for wine type 1
# <Response [200]>
# Added page 99 to database for wine type 1
# <Response [200]>
# Added page 100 to database for wine type 1
# <Response [200]>
# Added page 101 to database for wine type 1
# <Response [200]>
# Added page 102 to database for wine type 1
# <Response [200]>
# Added page 103 to database for wine type 1
# <Response [200]>
# Added page 104 to database for wine type 1
# <Response [200]>
# Added page 105 to database for wine type 1
# <Response [200]>
# Added page 106 to database for wine type 1
# <Response [200]>
# Added page 107 to database for wine type 1
# <Response [200]>
# Added page 108 to database for wine type 1
# <Response [200]>
# Added page 109 to database for wine type 1
# <Response [200]>
# Added page 110 to database for wine type 1
# <Response [200]>
# Added page 111 to database for wine type 1
# <Response [200]>
# Added page 112 to database for wine type 1
# <Response [200]>
# Added page 113 to database for wine type 1
# <Response [200]>
# Added page 114 to database for wine type 1
# <Response [200]>
# Added page 115 to database for wine type 1
# <Response [200]>
# Added page 116 to database for wine type 1
# <Response [200]>
# Added page 117 to database for wine type 1
# <Response [200]>
# Added page 118 to database for wine type 1
# <Response [200]>
# Added page 119 to database for wine type 1
# <Response [200]>
# Added page 120 to database for wine type 1
# <Response [200]>
# Added page 121 to database for wine type 1
# <Response [200]>
# Added page 122 to database for wine type 1
# <Response [200]>
# Added page 123 to database for wine type 1
# <Response [200]>
# Added page 124 to database for wine type 1
# <Response [200]>
# Added page 125 to database for wine type 1
# <Response [200]>
# Added page 126 to database for wine type 1
# <Response [200]>
# Added page 127 to database for wine type 1
# <Response [200]>
# Added page 128 to database for wine type 1
# <Response [200]>
# Added page 129 to database for wine type 1
# <Response [200]>
# Added page 130 to database for wine type 1
# <Response [200]>
# Added page 131 to database for wine type 1
# <Response [200]>
# Added page 132 to database for wine type 1
# <Response [200]>
# Added page 133 to database for wine type 1
# <Response [200]>
# Added page 134 to database for wine type 1
# <Response [200]>
# Added page 135 to database for wine type 1
# <Response [200]>
# Added page 136 to database for wine type 1
# <Response [200]>
# Added page 137 to database for wine type 1
# <Response [200]>
# Added page 138 to database for wine type 1
# <Response [200]>
# Added page 139 to database for wine type 1
# <Response [200]>
# Added page 140 to database for wine type 1
# <Response [200]>
# Added page 141 to database for wine type 1
# <Response [200]>
# Added page 142 to database for wine type 1
# <Response [200]>
# Added page 143 to database for wine type 1
# <Response [200]>
# Added page 144 to database for wine type 1
# <Response [200]>
# Added page 145 to database for wine type 1
# <Response [200]>
# Added page 146 to database for wine type 1
# <Response [200]>
# Added page 147 to database for wine type 1
# <Response [200]>
# Added page 148 to database for wine type 1
# <Response [200]>
# Added page 149 to database for wine type 1
# <Response [200]>
# Added page 150 to database for wine type 1
# <Response [200]>
# Added page 151 to database for wine type 1
# <Response [200]>
# Added page 152 to database for wine type 1
# <Response [200]>
# Added page 153 to database for wine type 1
# <Response [200]>
# Added page 154 to database for wine type 1
# <Response [200]>
# Added page 155 to database for wine type 1
# <Response [200]>
# Added page 156 to database for wine type 1
# <Response [200]>
# Added page 157 to database for wine type 1
# <Response [200]>
# Added page 158 to database for wine type 1
# <Response [200]>
# Added page 159 to database for wine type 1
# <Response [200]>
# Added page 160 to database for wine type 1
# <Response [200]>
# Added page 161 to database for wine type 1
# <Response [200]>
# Added page 162 to database for wine type 1
# <Response [200]>
# Added page 163 to database for wine type 1
# <Response [200]>
# Added page 164 to database for wine type 1
# <Response [200]>
# Added page 165 to database for wine type 1
# <Response [200]>
# Added page 166 to database for wine type 1
# <Response [200]>
# Added page 167 to database for wine type 1
# <Response [200]>
# Added page 168 to database for wine type 1
# <Response [200]>
# Added page 169 to database for wine type 1
# <Response [200]>
# Added page 170 to database for wine type 1
# <Response [200]>
# Added page 171 to database for wine type 1
# <Response [200]>
# Added page 172 to database for wine type 1
# <Response [200]>
# Added page 173 to database for wine type 1
# <Response [200]>
# Added page 174 to database for wine type 1
# <Response [200]>
# Added page 175 to database for wine type 1
# <Response [200]>
# Added page 176 to database for wine type 1
# <Response [200]>
# Added page 177 to database for wine type 1
# <Response [200]>
# Added page 178 to database for wine type 1
# <Response [200]>
# Added page 179 to database for wine type 1
# <Response [200]>
# Added page 180 to database for wine type 1
# <Response [200]>
# Added page 181 to database for wine type 1
# <Response [200]>
# Added page 182 to database for wine type 1
# <Response [200]>
# Added page 183 to database for wine type 1
# <Response [200]>
# Added page 184 to database for wine type 1
# <Response [200]>
# Added page 185 to database for wine type 1
# <Response [200]>
# Added page 186 to database for wine type 1
# <Response [200]>
# Added page 187 to database for wine type 1
# <Response [200]>
# Added page 188 to database for wine type 1
# <Response [200]>
# Added page 189 to database for wine type 1
# <Response [200]>
# Added page 190 to database for wine type 1
# <Response [200]>
# Added page 191 to database for wine type 1
# <Response [200]>
# Added page 192 to database for wine type 1
# <Response [200]>
# Added page 193 to database for wine type 1
# <Response [200]>
# Added page 194 to database for wine type 1
# <Response [200]>
# Added page 195 to database for wine type 1
# <Response [200]>
# Added page 196 to database for wine type 1
# <Response [200]>
# Added page 197 to database for wine type 1
# <Response [200]>
# Added page 198 to database for wine type 1
# <Response [200]>
# Added page 199 to database for wine type 1
# <Response [200]>
# Added page 200 to database for wine type 1
# <Response [200]>
# Added page 201 to database for wine type 1
# <Response [200]>
# Added page 202 to database for wine type 1
# <Response [200]>
# Added page 203 to database for wine type 1
# <Response [200]>
# Added page 204 to database for wine type 1
# <Response [200]>
# Added page 205 to database for wine type 1
# <Response [200]>
# Added page 206 to database for wine type 1
# <Response [200]>
# Added page 207 to database for wine type 1
# <Response [200]>
# Added page 208 to database for wine type 1
# <Response [200]>
# Added page 209 to database for wine type 1
# <Response [200]>
# Added page 210 to database for wine type 1
# <Response [200]>
# Added page 211 to database for wine type 1
# <Response [200]>
# Added page 212 to database for wine type 1
# <Response [200]>
# Added page 213 to database for wine type 1
# <Response [200]>
# Added page 214 to database for wine type 1
# <Response [200]>
# Added page 215 to database for wine type 1
# <Response [200]>
# Added page 216 to database for wine type 1
# <Response [200]>
# Added page 217 to database for wine type 1
# <Response [200]>
# Added page 218 to database for wine type 1
# <Response [200]>
# Added page 219 to database for wine type 1
# <Response [200]>
# Added page 220 to database for wine type 1
# <Response [200]>
# Added page 221 to database for wine type 1
# <Response [200]>
# Added page 222 to database for wine type 1
# <Response [200]>
# Added page 223 to database for wine type 1
# <Response [200]>
# Added page 224 to database for wine type 1
# <Response [200]>
# Added page 225 to database for wine type 1
# <Response [200]>
# Added page 226 to database for wine type 1
# <Response [200]>
# Added page 227 to database for wine type 1
# <Response [200]>
# Added page 228 to database for wine type 1
# <Response [200]>
# Added page 229 to database for wine type 1
# <Response [200]>
# Added page 230 to database for wine type 1
# <Response [200]>
# Added page 231 to database for wine type 1
# <Response [200]>
# Added page 232 to database for wine type 1
# <Response [200]>
# Added page 233 to database for wine type 1
# <Response [200]>
# Added page 234 to database for wine type 1
# <Response [200]>
# Added page 235 to database for wine type 1
# <Response [200]>
# Added page 236 to database for wine type 1
# <Response [200]>
# Added page 237 to database for wine type 1
# <Response [200]>
# Added page 238 to database for wine type 1
# <Response [200]>
# Added page 239 to database for wine type 1
# <Response [200]>
# Added page 240 to database for wine type 1
# <Response [200]>
# Added page 241 to database for wine type 1
# <Response [200]>
# Added page 242 to database for wine type 1
# <Response [200]>
# Added page 243 to database for wine type 1
# <Response [200]>
# Added page 244 to database for wine type 1
# <Response [200]>
# Added page 245 to database for wine type 1
# <Response [200]>
# Added page 246 to database for wine type 1
# <Response [200]>
# Added page 247 to database for wine type 1
# <Response [200]>
# Added page 248 to database for wine type 1
# <Response [200]>
# Added page 249 to database for wine type 1
# <Response [200]>
# Added page 250 to database for wine type 1
# <Response [200]>
# Added page 251 to database for wine type 1
# <Response [200]>
# Added page 252 to database for wine type 1
# <Response [200]>
# Added page 253 to database for wine type 1
# <Response [200]>
# Added page 254 to database for wine type 1
# <Response [200]>
# Added page 255 to database for wine type 1
# <Response [200]>
# Added page 256 to database for wine type 1
# <Response [200]>
# Added page 257 to database for wine type 1
# <Response [200]>
# Added page 258 to database for wine type 1
# <Response [200]>
# Added page 259 to database for wine type 1
# <Response [200]>
# Added page 260 to database for wine type 1
# <Response [200]>
# Added page 261 to database for wine type 1
# <Response [200]>
# Added page 262 to database for wine type 1
# <Response [200]>
# Added page 263 to database for wine type 1
# <Response [200]>
# Added page 264 to database for wine type 1
# <Response [200]>
# Added page 265 to database for wine type 1
# <Response [200]>
# Added page 266 to database for wine type 1
# <Response [200]>
# Added page 267 to database for wine type 1
# <Response [200]>
# Added page 268 to database for wine type 1
# <Response [200]>
# Added page 269 to database for wine type 1
# <Response [200]>
# Added page 270 to database for wine type 1
# <Response [200]>
# Added page 271 to database for wine type 1
# <Response [200]>
# Added page 272 to database for wine type 1
# <Response [200]>
# Added page 273 to database for wine type 1
# <Response [200]>
# Added page 274 to database for wine type 1
# <Response [200]>
# Added page 275 to database for wine type 1
# <Response [200]>
# Added page 276 to database for wine type 1
# <Response [200]>
# Added page 277 to database for wine type 1
# <Response [200]>
# Added page 278 to database for wine type 1
# <Response [200]>
# Added page 279 to database for wine type 1
# <Response [200]>
# Added page 280 to database for wine type 1
# <Response [200]>
# Added page 281 to database for wine type 1
# <Response [200]>
# Added page 282 to database for wine type 1
# <Response [200]>
# Added page 283 to database for wine type 1
# <Response [200]>
# Added page 284 to database for wine type 1
# <Response [200]>
# Added page 285 to database for wine type 1
# <Response [200]>
# Added page 286 to database for wine type 1
# <Response [200]>
# Added page 287 to database for wine type 1
# <Response [200]>
# Added page 288 to database for wine type 1
# <Response [200]>
# Added page 289 to database for wine type 1
# <Response [200]>
# Added page 290 to database for wine type 1
# <Response [200]>
# Added page 291 to database for wine type 1
# <Response [200]>
# Added page 292 to database for wine type 1
# <Response [200]>
# Added page 293 to database for wine type 1
# <Response [200]>
# Added page 294 to database for wine type 1
# <Response [200]>
# Added page 295 to database for wine type 1
# <Response [200]>
# Added page 296 to database for wine type 1
# <Response [200]>
# Added page 297 to database for wine type 1
# <Response [200]>
# Added page 298 to database for wine type 1
# <Response [200]>
# Added page 299 to database for wine type 1
# <Response [200]>
# Added page 300 to database for wine type 1
# <Response [200]>
# Added page 301 to database for wine type 1
# <Response [200]>
# Added page 302 to database for wine type 1
# <Response [200]>
# Added page 303 to database for wine type 1
# <Response [200]>
# Added page 304 to database for wine type 1
# <Response [200]>
# Added page 305 to database for wine type 1
# <Response [200]>
# Added page 306 to database for wine type 1
# <Response [200]>
# Added page 307 to database for wine type 1
# <Response [200]>
# Added page 308 to database for wine type 1
# <Response [200]>
# Added page 309 to database for wine type 1
# <Response [200]>
# Added page 310 to database for wine type 1
# <Response [200]>
# Added page 311 to database for wine type 1
# <Response [200]>
# Added page 312 to database for wine type 1
# <Response [200]>
# Added page 313 to database for wine type 1
# <Response [200]>
# Added page 314 to database for wine type 1
# <Response [200]>
# Added page 315 to database for wine type 1
# <Response [200]>
# Added page 316 to database for wine type 1
# <Response [200]>
# Added page 317 to database for wine type 1
# <Response [200]>
# Added page 318 to database for wine type 1
# <Response [200]>
# Added page 319 to database for wine type 1
# <Response [200]>
# Added page 320 to database for wine type 1
# <Response [200]>
# Added page 321 to database for wine type 1
# <Response [200]>
# Added page 322 to database for wine type 1
# <Response [200]>
# Added page 323 to database for wine type 1
# <Response [200]>
# Added page 324 to database for wine type 1
# <Response [200]>
# Added page 325 to database for wine type 1
# <Response [200]>
# Added page 326 to database for wine type 1
# <Response [200]>
# Added page 327 to database for wine type 1
# <Response [200]>
# Added page 328 to database for wine type 1
# <Response [200]>
# Added page 329 to database for wine type 1
# <Response [200]>
# Added page 330 to database for wine type 1
# <Response [200]>
# Added page 331 to database for wine type 1
# <Response [200]>
# Added page 332 to database for wine type 1
# <Response [200]>
# Added page 333 to database for wine type 1
# <Response [200]>
# Added page 334 to database for wine type 1
# <Response [200]>
# Added page 335 to database for wine type 1
# <Response [200]>
# Added page 336 to database for wine type 1
# <Response [200]>
# Added page 337 to database for wine type 1
# <Response [200]>
# Added page 338 to database for wine type 1
# <Response [200]>
# Added page 339 to database for wine type 1
# <Response [200]>
# Added page 340 to database for wine type 1
# <Response [200]>
# Added page 341 to database for wine type 1
# <Response [200]>
# Added page 342 to database for wine type 1
# <Response [200]>
# Added page 343 to database for wine type 1
# <Response [200]>
# Added page 344 to database for wine type 1
# <Response [200]>
# Added page 345 to database for wine type 1
# <Response [200]>
# Added page 346 to database for wine type 1
# <Response [200]>
# Added page 347 to database for wine type 1
# <Response [200]>
# Added page 348 to database for wine type 1
# <Response [200]>
# Added page 349 to database for wine type 1
# <Response [200]>
# Added page 350 to database for wine type 1
# <Response [200]>
# Added page 351 to database for wine type 1
# <Response [200]>
# Added page 352 to database for wine type 1
# <Response [200]>
# Added page 353 to database for wine type 1
# <Response [200]>
# Added page 354 to database for wine type 1
# <Response [200]>
# Added page 355 to database for wine type 1
# <Response [200]>
# Added page 356 to database for wine type 1
# <Response [200]>
# Added page 357 to database for wine type 1
# <Response [200]>
# Added page 358 to database for wine type 1
# <Response [200]>
# Added page 359 to database for wine type 1
# <Response [200]>
# Added page 360 to database for wine type 1
# <Response [200]>
# Added page 361 to database for wine type 1
# <Response [200]>
# Added page 362 to database for wine type 1
# <Response [200]>
# Added page 363 to database for wine type 1
# <Response [200]>
# Added page 364 to database for wine type 1
# <Response [200]>
# Added page 365 to database for wine type 1
# <Response [200]>
# Added page 366 to database for wine type 1
# <Response [200]>
# Added page 367 to database for wine type 1
# <Response [200]>
# Added page 368 to database for wine type 1
# <Response [200]>
# Added page 369 to database for wine type 1
# <Response [200]>
# Added page 370 to database for wine type 1
# <Response [200]>
# Added page 371 to database for wine type 1
# <Response [200]>
# Added page 372 to database for wine type 1
# <Response [200]>
# Added page 373 to database for wine type 1
# <Response [200]>
# Added page 374 to database for wine type 1
# <Response [200]>
# Added page 375 to database for wine type 1
# <Response [200]>
# Added page 376 to database for wine type 1
# <Response [200]>
# Added page 377 to database for wine type 1
# <Response [200]>
# Added page 378 to database for wine type 1
# <Response [200]>
# Added page 379 to database for wine type 1
# <Response [200]>
# Added page 380 to database for wine type 1
# <Response [200]>
# Added page 381 to database for wine type 1
# <Response [200]>
# Added page 382 to database for wine type 1
# <Response [200]>
# Added page 383 to database for wine type 1
# <Response [200]>
# Added page 384 to database for wine type 1
# <Response [200]>
# Added page 385 to database for wine type 1
# <Response [200]>
# Added page 386 to database for wine type 1
# <Response [200]>
# Added page 387 to database for wine type 1
# <Response [200]>
# Added page 388 to database for wine type 1
# <Response [200]>
# Added page 389 to database for wine type 1
# <Response [200]>
# Added page 390 to database for wine type 1
# <Response [200]>
# Added page 391 to database for wine type 1
# <Response [200]>
# Added page 392 to database for wine type 1
# <Response [200]>
# Added page 393 to database for wine type 1
# <Response [200]>
# Added page 394 to database for wine type 1
# <Response [200]>
# Added page 395 to database for wine type 1
# <Response [200]>
# Added page 396 to database for wine type 1
# <Response [200]>
# Added page 397 to database for wine type 1
# <Response [200]>
# Added page 398 to database for wine type 1
# <Response [200]>
# Added page 399 to database for wine type 1
# <Response [200]>
# Added page 400 to database for wine type 1
# <Response [200]>
# Added page 401 to database for wine type 1
# <Response [200]>
# Added page 402 to database for wine type 1
# <Response [200]>
# Added page 403 to database for wine type 1
# <Response [200]>
# Added page 404 to database for wine type 1
# <Response [200]>
# Added page 405 to database for wine type 1
# <Response [200]>
# Added page 406 to database for wine type 1
# <Response [200]>
# Added page 407 to database for wine type 1
# <Response [200]>
# Added page 408 to database for wine type 1
# <Response [200]>
# Added page 409 to database for wine type 1
# <Response [200]>
# Added page 410 to database for wine type 1
# <Response [200]>
# Added page 411 to database for wine type 1
# <Response [200]>
# Added page 412 to database for wine type 1
# <Response [200]>
# Added page 413 to database for wine type 1
# <Response [200]>
# Added page 414 to database for wine type 1
# <Response [200]>
# Added page 415 to database for wine type 1
# <Response [200]>
# Added page 416 to database for wine type 1
# <Response [200]>
# Added page 417 to database for wine type 1
# <Response [200]>
# Added page 418 to database for wine type 1
# <Response [200]>
# Added page 419 to database for wine type 1
# <Response [200]>
# Added page 420 to database for wine type 1
# <Response [200]>
# Added page 421 to database for wine type 1
# <Response [200]>
# Added page 422 to database for wine type 1
# <Response [200]>
# Added page 423 to database for wine type 1
# <Response [200]>
# Added page 424 to database for wine type 1
# <Response [200]>
# Added page 425 to database for wine type 1
# <Response [200]>
# Added page 426 to database for wine type 1
# <Response [200]>
# Added page 427 to database for wine type 1
# <Response [200]>
# Added page 428 to database for wine type 1
# <Response [200]>
# Added page 429 to database for wine type 1
# <Response [200]>
# Added page 430 to database for wine type 1
# <Response [200]>
# Added page 431 to database for wine type 1
# <Response [200]>
# Added page 432 to database for wine type 1
# <Response [200]>
# Added page 433 to database for wine type 1
# <Response [200]>
# Added page 434 to database for wine type 1
# <Response [200]>
# Added page 435 to database for wine type 1
# <Response [200]>
# Added page 436 to database for wine type 1
# <Response [200]>
# Added page 437 to database for wine type 1
# <Response [200]>
# Added page 438 to database for wine type 1
# <Response [200]>
# Added page 439 to database for wine type 1
# <Response [200]>
# Added page 440 to database for wine type 1
# <Response [200]>
# Added page 441 to database for wine type 1
# <Response [200]>
# Added page 442 to database for wine type 1
# <Response [200]>
# Added page 443 to database for wine type 1
# <Response [200]>
# Added page 444 to database for wine type 1
# <Response [200]>
# Added page 445 to database for wine type 1
# <Response [200]>
# Added page 446 to database for wine type 1
# <Response [200]>
# Added page 447 to database for wine type 1
# <Response [200]>
# Added page 448 to database for wine type 1
# <Response [200]>
# Added page 449 to database for wine type 1
# <Response [200]>
# Added page 450 to database for wine type 1
# <Response [200]>
# Added page 451 to database for wine type 1
# <Response [200]>
# Added page 452 to database for wine type 1
# <Response [200]>
# Added page 453 to database for wine type 1
# <Response [200]>
# Added page 454 to database for wine type 1
# <Response [200]>
# Added page 455 to database for wine type 1
# <Response [200]>
# Added page 456 to database for wine type 1
# <Response [200]>
# Added page 457 to database for wine type 1
# <Response [200]>
# Added page 458 to database for wine type 1
# <Response [200]>
# Added page 459 to database for wine type 1
# <Response [200]>
# Added page 460 to database for wine type 1
# <Response [200]>
# Added page 461 to database for wine type 1
# <Response [200]>
# Added page 462 to database for wine type 1
# <Response [200]>
# Added page 463 to database for wine type 1
# <Response [200]>
# Added page 464 to database for wine type 1
# <Response [200]>
# Added page 465 to database for wine type 1
# <Response [200]>
# Added page 466 to database for wine type 1
# <Response [200]>
# Added page 467 to database for wine type 1
# <Response [200]>
# Added page 468 to database for wine type 1
# <Response [200]>
# Added page 469 to database for wine type 1
# <Response [200]>
# Added page 470 to database for wine type 1
# <Response [200]>
# Added page 471 to database for wine type 1
# <Response [200]>
# Added page 472 to database for wine type 1
# <Response [200]>
# Added page 473 to database for wine type 1
# <Response [200]>
# Added page 474 to database for wine type 1
# <Response [200]>
# Added page 475 to database for wine type 1
# <Response [200]>
# Added page 476 to database for wine type 1
# <Response [200]>
# Added page 477 to database for wine type 1
# <Response [200]>
# Added page 478 to database for wine type 1
# <Response [200]>
# Added page 479 to database for wine type 1
# <Response [200]>
# Added page 480 to database for wine type 1
# <Response [200]>
# Added page 481 to database for wine type 1
# <Response [200]>
# Added page 482 to database for wine type 1
# <Response [200]>
# Added page 483 to database for wine type 1
# <Response [200]>
# Added page 484 to database for wine type 1
# <Response [200]>
# Added page 485 to database for wine type 1
# <Response [200]>
# Added page 486 to database for wine type 1
# <Response [200]>
# Added page 487 to database for wine type 1
# <Response [200]>
# Added page 488 to database for wine type 1
# <Response [200]>
# Added page 489 to database for wine type 1
# <Response [200]>
# Added page 490 to database for wine type 1
# <Response [200]>
# Added page 491 to database for wine type 1
# <Response [200]>
# Added page 492 to database for wine type 1
# <Response [200]>
# Added page 493 to database for wine type 1
# <Response [200]>
# Added page 494 to database for wine type 1
# <Response [200]>
# Added page 495 to database for wine type 1
# <Response [200]>
# Added page 496 to database for wine type 1
# <Response [200]>
# Added page 497 to database for wine type 1
# <Response [200]>
# Added page 498 to database for wine type 1
# <Response [200]>
# Added page 499 to database for wine type 1
# <Response [200]>
# Added page 500 to database for wine type 1
# <Response [200]>
# Added page 501 to database for wine type 1
# <Response [200]>
# Added page 502 to database for wine type 1
# <Response [200]>
# Added page 503 to database for wine type 1
# <Response [200]>
# Added page 504 to database for wine type 1
# <Response [200]>
# Added page 505 to database for wine type 1
# <Response [200]>
# Added page 506 to database for wine type 1
# <Response [200]>
# Added page 507 to database for wine type 1
# <Response [200]>
# Added page 508 to database for wine type 1
# <Response [200]>
# Added page 509 to database for wine type 1
# <Response [200]>
# Added page 510 to database for wine type 1
# <Response [200]>
# Added page 511 to database for wine type 1
# <Response [200]>
# Added page 512 to database for wine type 1
# <Response [200]>
# Added page 513 to database for wine type 1
# <Response [200]>
# Added page 514 to database for wine type 1
# <Response [200]>
# Added page 515 to database for wine type 1
# <Response [200]>
# Added page 516 to database for wine type 1
# <Response [200]>
# Added page 517 to database for wine type 1
# <Response [200]>
# Added page 518 to database for wine type 1
# <Response [200]>
# Added page 519 to database for wine type 1
# <Response [200]>
# Added page 520 to database for wine type 1
# <Response [200]>
# Added page 521 to database for wine type 1
# <Response [200]>
# Added page 522 to database for wine type 1
# <Response [200]>
# Added page 523 to database for wine type 1
# <Response [200]>
# Added page 524 to database for wine type 1
# <Response [200]>
# Added page 525 to database for wine type 1
# <Response [200]>
# Added page 526 to database for wine type 1
# <Response [200]>
# Added page 527 to database for wine type 1
# <Response [200]>
# Added page 528 to database for wine type 1
# <Response [200]>
# Added page 529 to database for wine type 1
# <Response [200]>
# Added page 530 to database for wine type 1
# <Response [200]>
# Added page 531 to database for wine type 1
# <Response [200]>
# Added page 532 to database for wine type 1
# <Response [200]>
# Added page 533 to database for wine type 1
# <Response [200]>
# Added page 534 to database for wine type 1
# <Response [200]>
# Added page 535 to database for wine type 1
# <Response [200]>
# Added page 536 to database for wine type 1
# <Response [200]>
# Added page 537 to database for wine type 1
# <Response [200]>
# Added page 538 to database for wine type 1
# <Response [200]>
# Added page 539 to database for wine type 1
# <Response [200]>
# Added page 540 to database for wine type 1
# <Response [200]>
# Added page 541 to database for wine type 1
# <Response [200]>
# Added page 542 to database for wine type 1
# <Response [200]>
# Added page 543 to database for wine type 1
# <Response [200]>
# Added page 544 to database for wine type 1
# <Response [200]>
# Added page 545 to database for wine type 1
# <Response [200]>
# Added page 546 to database for wine type 1
# <Response [200]>
# Added page 547 to database for wine type 1
# <Response [200]>
# Added page 548 to database for wine type 1
# <Response [200]>
# Added page 549 to database for wine type 1
# <Response [200]>
# Added page 550 to database for wine type 1
# <Response [200]>
# Added page 551 to database for wine type 1
# <Response [200]>
# Added page 552 to database for wine type 1
# <Response [200]>
# Added page 553 to database for wine type 1
# <Response [200]>
# Added page 554 to database for wine type 1
# <Response [200]>
# Added page 555 to database for wine type 1
# <Response [200]>
# Added page 556 to database for wine type 1
# <Response [200]>
# Added page 557 to database for wine type 1
# <Response [200]>
# Added page 558 to database for wine type 1
# <Response [200]>
# Added page 559 to database for wine type 1
# <Response [200]>
# Added page 560 to database for wine type 1
# <Response [200]>
# Added page 561 to database for wine type 1
# <Response [200]>
# Added page 562 to database for wine type 1
# <Response [200]>
# Added page 563 to database for wine type 1
# <Response [200]>
# Added page 564 to database for wine type 1
# <Response [200]>
# Added page 565 to database for wine type 1
# <Response [200]>
# Added page 566 to database for wine type 1
# <Response [200]>
# Added page 567 to database for wine type 1
# <Response [200]>
# Added page 568 to database for wine type 1
# <Response [200]>
# Added page 569 to database for wine type 1
# <Response [200]>
# Added page 570 to database for wine type 1
# <Response [200]>
# Added page 571 to database for wine type 1
# <Response [200]>
# Added page 572 to database for wine type 1
# <Response [200]>
# Added page 573 to database for wine type 1
# <Response [200]>
# Added page 574 to database for wine type 1
# <Response [200]>
# Added page 575 to database for wine type 1
# <Response [200]>
# Added page 576 to database for wine type 1
# <Response [200]>
# Added page 577 to database for wine type 1
# <Response [200]>
# Added page 578 to database for wine type 1
# <Response [200]>
# Added page 579 to database for wine type 1
# <Response [200]>
# Added page 580 to database for wine type 1
# <Response [200]>
# Added page 581 to database for wine type 1
# <Response [200]>
# Added page 582 to database for wine type 1
# <Response [200]>
# Added page 583 to database for wine type 1
# <Response [200]>
# Added page 584 to database for wine type 1
# <Response [200]>
# Added page 585 to database for wine type 1
# <Response [200]>
# Added page 586 to database for wine type 1
# <Response [200]>
# Added page 587 to database for wine type 1
# <Response [200]>
# Added page 588 to database for wine type 1
# <Response [200]>
# Added page 589 to database for wine type 1
# <Response [200]>
# Added page 590 to database for wine type 1
# <Response [200]>
# Added page 591 to database for wine type 1
# <Response [200]>
# Added page 592 to database for wine type 1
# <Response [200]>
# Added page 593 to database for wine type 1
# <Response [200]>
# Added page 594 to database for wine type 1
# <Response [200]>
# Added page 595 to database for wine type 1
# <Response [200]>
# Added page 596 to database for wine type 1
# <Response [200]>
# Added page 597 to database for wine type 1
# <Response [200]>
# Added page 598 to database for wine type 1
# <Response [200]>
# Added page 599 to database for wine type 1
# <Response [200]>
# Added page 600 to database for wine type 1
# <Response [200]>
# Added page 601 to database for wine type 1
# <Response [200]>
# Added page 602 to database for wine type 1
# <Response [200]>
# Added page 603 to database for wine type 1
# <Response [200]>
# Added page 604 to database for wine type 1
# <Response [200]>
# Added page 605 to database for wine type 1
# <Response [200]>
# Added page 606 to database for wine type 1
# <Response [200]>
# Added page 607 to database for wine type 1
# <Response [200]>
# Added page 608 to database for wine type 1
# <Response [200]>
# Added page 609 to database for wine type 1
# <Response [200]>
# Added page 610 to database for wine type 1
# <Response [200]>
# Added page 611 to database for wine type 1
# <Response [200]>
# Added page 612 to database for wine type 1
# <Response [200]>
# Added page 613 to database for wine type 1
# <Response [200]>
# Added page 614 to database for wine type 1
# <Response [200]>
# Added page 615 to database for wine type 1
# <Response [200]>
# Added page 616 to database for wine type 1
# <Response [200]>
# Added page 617 to database for wine type 1
# <Response [200]>
# Added page 618 to database for wine type 1
# <Response [200]>
# Added page 619 to database for wine type 1
# <Response [200]>
# Added page 620 to database for wine type 1
# <Response [200]>
# Added page 621 to database for wine type 1
# <Response [200]>
# Added page 622 to database for wine type 1
# <Response [200]>
# Added page 623 to database for wine type 1
# <Response [200]>
# Added page 624 to database for wine type 1
# <Response [200]>
# Added page 625 to database for wine type 1
# <Response [200]>
# Added page 626 to database for wine type 1
# <Response [200]>
# Added page 627 to database for wine type 1
# <Response [200]>
# Added page 628 to database for wine type 1
# <Response [200]>
# Added page 629 to database for wine type 1
# <Response [200]>
# Added page 630 to database for wine type 1
# <Response [200]>
# Added page 631 to database for wine type 1
# <Response [200]>
# Added page 632 to database for wine type 1
# <Response [200]>
# Added page 633 to database for wine type 1
# <Response [200]>
# Added page 634 to database for wine type 1
# <Response [200]>
# Added page 635 to database for wine type 1
# <Response [200]>
# Added page 636 to database for wine type 1
# <Response [200]>
# Added page 637 to database for wine type 1
# <Response [200]>
# Added page 638 to database for wine type 1
# <Response [200]>
# Added page 639 to database for wine type 1
# <Response [200]>
# Added page 640 to database for wine type 1
# <Response [200]>
# Added page 641 to database for wine type 1
# <Response [200]>
# Added page 642 to database for wine type 1
# <Response [200]>
# Added page 643 to database for wine type 1
# <Response [200]>
# Added page 644 to database for wine type 1
# <Response [200]>
# Added page 645 to database for wine type 1
# <Response [200]>
# Added page 646 to database for wine type 1
# <Response [200]>
# Added page 647 to database for wine type 1
# <Response [200]>
# Added page 648 to database for wine type 1
# <Response [200]>
# Added page 649 to database for wine type 1
# <Response [200]>
# Added page 650 to database for wine type 1
# <Response [200]>
# Added page 651 to database for wine type 1
# <Response [200]>
# Added page 652 to database for wine type 1
# <Response [200]>
# Added page 653 to database for wine type 1
# <Response [200]>
# Added page 654 to database for wine type 1
# <Response [200]>
# Added page 655 to database for wine type 1
# <Response [200]>
# Added page 656 to database for wine type 1
# <Response [200]>
# Added page 657 to database for wine type 1
# <Response [200]>
# Added page 658 to database for wine type 1
# <Response [200]>
# Added page 659 to database for wine type 1
# <Response [200]>
# Added page 660 to database for wine type 1
# <Response [200]>
# Added page 661 to database for wine type 1
# <Response [200]>
# Added page 662 to database for wine type 1
# <Response [200]>
# Added page 663 to database for wine type 1
# <Response [200]>
# Added page 664 to database for wine type 1
# <Response [200]>
# Added page 665 to database for wine type 1
# <Response [200]>
# Added page 666 to database for wine type 1
# <Response [200]>
# Added page 667 to database for wine type 1
# <Response [200]>
# Added page 668 to database for wine type 1
# <Response [200]>
# Added page 669 to database for wine type 1
# <Response [200]>
# Added page 670 to database for wine type 1
# <Response [200]>
# Added page 671 to database for wine type 1
# <Response [200]>
# Added page 672 to database for wine type 1
# <Response [200]>
# Added page 673 to database for wine type 1
# <Response [200]>
# Added page 674 to database for wine type 1
# <Response [200]>
# Added page 675 to database for wine type 1
# <Response [200]>
# Added page 676 to database for wine type 1
# <Response [200]>
# Added page 677 to database for wine type 1
# <Response [200]>
# Added page 678 to database for wine type 1
# <Response [200]>
# Added page 679 to database for wine type 1
# <Response [200]>
# Added page 680 to database for wine type 1
# <Response [200]>
# Added page 681 to database for wine type 1
# <Response [200]>
# Added page 682 to database for wine type 1
# <Response [200]>
# Added page 683 to database for wine type 1
# <Response [200]>
# Added page 684 to database for wine type 1
# <Response [200]>
# Added page 685 to database for wine type 1
# <Response [200]>
# Added page 686 to database for wine type 1
# <Response [200]>
# Added page 687 to database for wine type 1
# <Response [200]>
# Added page 688 to database for wine type 1
# <Response [200]>
# Added page 689 to database for wine type 1
# <Response [200]>
# Added page 690 to database for wine type 1
# <Response [200]>
# Added page 691 to database for wine type 1
# <Response [200]>
# Added page 692 to database for wine type 1
# <Response [200]>
# Added page 693 to database for wine type 1
# <Response [200]>
# Added page 694 to database for wine type 1
# <Response [200]>
# Added page 695 to database for wine type 1
# <Response [200]>
# Added page 696 to database for wine type 1
# <Response [200]>
# Added page 697 to database for wine type 1
# <Response [200]>
# Added page 698 to database for wine type 1
# <Response [200]>
# Added page 699 to database for wine type 1
# <Response [200]>
# Added page 700 to database for wine type 1
# <Response [200]>
# Added page 701 to database for wine type 1
# <Response [200]>
# Added page 702 to database for wine type 1
# <Response [200]>
# Added page 703 to database for wine type 1
# <Response [200]>
# Added page 704 to database for wine type 1
# <Response [200]>
# Added page 705 to database for wine type 1
# <Response [200]>
# Added page 706 to database for wine type 1
# <Response [200]>
# Added page 707 to database for wine type 1
# <Response [200]>
# Added page 708 to database for wine type 1
# <Response [200]>
# Added page 709 to database for wine type 1
# <Response [200]>
# Added page 710 to database for wine type 1
# <Response [200]>
# Added page 711 to database for wine type 1
# <Response [200]>
# Added page 712 to database for wine type 1
# <Response [200]>
# Added page 713 to database for wine type 1
# <Response [200]>
# Added page 714 to database for wine type 1
# <Response [200]>
# Added page 715 to database for wine type 1
# <Response [200]>
# Added page 716 to database for wine type 1
# <Response [200]>
# Added page 717 to database for wine type 1
# <Response [200]>
# Added page 718 to database for wine type 1
# <Response [200]>
# Added page 719 to database for wine type 1
# <Response [200]>
# Added page 720 to database for wine type 1
# <Response [200]>
# Added page 721 to database for wine type 1
# <Response [200]>
# Added page 722 to database for wine type 1
# <Response [200]>
# Added page 723 to database for wine type 1
# <Response [200]>
# Added page 724 to database for wine type 1
# <Response [200]>
# Added page 725 to database for wine type 1
# <Response [200]>
# Added page 726 to database for wine type 1
# <Response [200]>
# Added page 727 to database for wine type 1
# <Response [200]>
# Added page 728 to database for wine type 1
# <Response [200]>
# Added page 729 to database for wine type 1
# <Response [200]>
# Added page 730 to database for wine type 1
# <Response [200]>
# Added page 731 to database for wine type 1
# <Response [200]>
# Added page 732 to database for wine type 1
# <Response [200]>
# Added page 733 to database for wine type 1
# <Response [200]>
# Added page 734 to database for wine type 1
# <Response [200]>
# Added page 735 to database for wine type 1
# <Response [200]>
# Added page 736 to database for wine type 1
# <Response [200]>
# Added page 737 to database for wine type 1
# <Response [200]>
# Added page 738 to database for wine type 1
# <Response [200]>
# Added page 739 to database for wine type 1
# <Response [200]>
# Added page 740 to database for wine type 1
# <Response [200]>
# Added page 741 to database for wine type 1
# <Response [200]>
# Added page 742 to database for wine type 1
# <Response [200]>
# Added page 743 to database for wine type 1
# <Response [200]>
# Added page 744 to database for wine type 1
# <Response [200]>
# Added page 745 to database for wine type 1
# <Response [200]>
# Added page 746 to database for wine type 1
# <Response [200]>
# Added page 747 to database for wine type 1
# <Response [200]>
# Added page 748 to database for wine type 1
# <Response [200]>
# Added page 749 to database for wine type 1
# <Response [200]>
# Added page 750 to database for wine type 1
# <Response [200]>
# Added page 751 to database for wine type 1
# <Response [200]>
# Added page 752 to database for wine type 1
# <Response [200]>
# Added page 753 to database for wine type 1
# <Response [200]>
# Added page 754 to database for wine type 1
# <Response [200]>
# Added page 755 to database for wine type 1
# <Response [200]>
# Added page 756 to database for wine type 1
# <Response [200]>
# Added page 757 to database for wine type 1
# <Response [200]>
# Added page 758 to database for wine type 1
# <Response [200]>
# Added page 759 to database for wine type 1
# <Response [200]>
# Added page 760 to database for wine type 1
# <Response [200]>
# Added page 761 to database for wine type 1
# <Response [200]>
# Added page 762 to database for wine type 1
# <Response [200]>
# Added page 763 to database for wine type 1
# <Response [200]>
# Added page 764 to database for wine type 1
# <Response [200]>
# Added page 765 to database for wine type 1
# <Response [200]>
# Added page 766 to database for wine type 1
# <Response [200]>
# Added page 767 to database for wine type 1
# <Response [200]>
# Added page 768 to database for wine type 1
# <Response [200]>
# Added page 769 to database for wine type 1
# <Response [200]>
# Added page 770 to database for wine type 1
# <Response [200]>
# Added page 771 to database for wine type 1
# <Response [200]>
# Added page 772 to database for wine type 1
# <Response [200]>
# Added page 773 to database for wine type 1
# <Response [200]>
# Added page 774 to database for wine type 1
# <Response [200]>
# Added page 775 to database for wine type 1
# <Response [200]>
# Added page 776 to database for wine type 1
# <Response [200]>
# Added page 777 to database for wine type 1
# <Response [200]>
# Added page 778 to database for wine type 1
# <Response [200]>
# Added page 779 to database for wine type 1
# <Response [200]>
# Added page 780 to database for wine type 1
# <Response [200]>
# Added page 781 to database for wine type 1
# <Response [200]>
# Added page 782 to database for wine type 1
# <Response [200]>
# Added page 783 to database for wine type 1
# <Response [200]>
# Added page 784 to database for wine type 1
# <Response [200]>
# Added page 785 to database for wine type 1
# <Response [200]>
# Added page 786 to database for wine type 1
# <Response [200]>
# Added page 787 to database for wine type 1
# <Response [200]>
# Added page 788 to database for wine type 1
# <Response [200]>
# Added page 789 to database for wine type 1
# <Response [200]>
# Added page 790 to database for wine type 1
# <Response [200]>
# Added page 791 to database for wine type 1
# <Response [200]>
# Added page 792 to database for wine type 1
# <Response [200]>
# Added page 793 to database for wine type 1
# <Response [200]>
# Added page 794 to database for wine type 1
# <Response [200]>
# Added page 795 to database for wine type 1
# <Response [200]>
# Added page 796 to database for wine type 1
# <Response [200]>
# Added page 797 to database for wine type 1
# <Response [200]>
# Added page 798 to database for wine type 1
# <Response [200]>
# Added page 799 to database for wine type 1
# <Response [200]>
# Added page 800 to database for wine type 1
# <Response [200]>
# Added page 801 to database for wine type 1
# <Response [200]>
# ...
# Added page 641 to database for wine type 2
# <Response [200]>
# Added page 642 to database for wine type 2
# <Response [200]>
# Added page 643 to database for wine type 2
# <Response [200]>
# Added page 644 to database for wine type 2
# <Response [200]>
# Added page 645 to database for wine type 2
# <Response [200]>
# Added page 646 to database for wine type 2
# <Response [200]>
# Added page 647 to database for wine type 2
# <Response [200]>
# Added page 648 to database for wine type 2
# <Response [200]>
# Added page 649 to database for wine type 2
# <Response [200]>
# Added page 650 to database for wine type 2
# <Response [200]>
# Added page 651 to database for wine type 2
# <Response [200]>
# Added page 652 to database for wine type 2
# <Response [200]>
# Added page 653 to database for wine type 2
# <Response [200]>
# Added page 654 to database for wine type 2
# <Response [200]>
# Added page 655 to database for wine type 2
# <Response [200]>
# Added page 656 to database for wine type 2
# <Response [200]>
# Added page 657 to database for wine type 2
# <Response [200]>
# Added page 658 to database for wine type 2
# <Response [200]>
# Added page 659 to database for wine type 2
# <Response [200]>
# Added page 660 to database for wine type 2
# <Response [200]>
# Added page 661 to database for wine type 2
# <Response [200]>
# Added page 662 to database for wine type 2
# <Response [200]>
# Added page 663 to database for wine type 2
# <Response [200]>
# Added page 664 to database for wine type 2
# <Response [200]>
# Added page 665 to database for wine type 2
# <Response [200]>
# Added page 666 to database for wine type 2
# <Response [200]>
# Added page 667 to database for wine type 2
# <Response [200]>
# Added page 668 to database for wine type 2
# <Response [200]>
# Added page 669 to database for wine type 2
# <Response [200]>
# Added page 670 to database for wine type 2
# <Response [200]>
# Added page 671 to database for wine type 2
# <Response [200]>
# Added page 672 to database for wine type 2
# <Response [200]>
# Added page 673 to database for wine type 2
# <Response [200]>
# Added page 674 to database for wine type 2
# <Response [200]>
# Added page 675 to database for wine type 2
# <Response [200]>
# Added page 676 to database for wine type 2
# <Response [200]>
# Added page 677 to database for wine type 2
# <Response [200]>
# Added page 678 to database for wine type 2
# <Response [200]>
# Added page 679 to database for wine type 2
# <Response [200]>
# Added page 680 to database for wine type 2
# <Response [200]>
# Added page 681 to database for wine type 2
# <Response [200]>
# Added page 682 to database for wine type 2
# <Response [200]>
# Added page 683 to database for wine type 2
# <Response [200]>
# Added page 684 to database for wine type 2
# <Response [200]>
# Added page 685 to database for wine type 2
# <Response [200]>
# Added page 686 to database for wine type 2
# <Response [200]>
# Added page 687 to database for wine type 2
# <Response [200]>
# Added page 688 to database for wine type 2
# <Response [200]>
# Added page 689 to database for wine type 2
# <Response [200]>
# Added page 690 to database for wine type 2
# <Response [200]>
# Added page 691 to database for wine type 2
# <Response [200]>
# Added page 692 to database for wine type 2
# <Response [200]>
# Added page 693 to database for wine type 2
# <Response [200]>
# Added page 694 to database for wine type 2
# <Response [200]>
# Added page 695 to database for wine type 2
# <Response [200]>
# Added page 696 to database for wine type 2
# <Response [200]>
# Added page 697 to database for wine type 2
# <Response [200]>
# Added page 698 to database for wine type 2
# <Response [200]>
# Added page 699 to database for wine type 2
# <Response [200]>
# Added page 700 to database for wine type 2
# <Response [200]>
# Added page 701 to database for wine type 2
# <Response [200]>
# Added page 702 to database for wine type 2
# <Response [200]>
# Added page 703 to database for wine type 2
# <Response [200]>
# Added page 704 to database for wine type 2
# <Response [200]>
# Added page 705 to database for wine type 2
# <Response [200]>
# Added page 706 to database for wine type 2
# <Response [200]>
# Added page 707 to database for wine type 2
# <Response [200]>
# Added page 708 to database for wine type 2
# <Response [200]>
# Added page 709 to database for wine type 2
# <Response [200]>
# Added page 710 to database for wine type 2
# <Response [200]>
# Added page 711 to database for wine type 2
# <Response [200]>
# Added page 712 to database for wine type 2
# <Response [200]>
# Added page 713 to database for wine type 2
# <Response [200]>
# Added page 714 to database for wine type 2
# <Response [200]>
# Added page 715 to database for wine type 2
# <Response [200]>
# <Response [200]>
# Added page 1 to database for wine type 4
# <Response [200]>
# Added page 2 to database for wine type 4
# <Response [200]>
# Added page 3 to database for wine type 4
# <Response [200]>
# Added page 4 to database for wine type 4
# <Response [200]>
# Added page 5 to database for wine type 4
# <Response [200]>
# Added page 6 to database for wine type 4
# <Response [200]>
# Added page 7 to database for wine type 4
# <Response [200]>
# Added page 8 to database for wine type 4
# <Response [200]>
# Added page 9 to database for wine type 4
# <Response [200]>
# Added page 10 to database for wine type 4
# <Response [200]>
# Added page 11 to database for wine type 4
# <Response [200]>
# Added page 12 to database for wine type 4
# <Response [200]>
# Added page 13 to database for wine type 4
# <Response [200]>
# Added page 14 to database for wine type 4
# <Response [200]>
# Added page 15 to database for wine type 4
# <Response [200]>
# Added page 16 to database for wine type 4
# <Response [200]>
# Added page 17 to database for wine type 4
# <Response [200]>
# Added page 18 to database for wine type 4
# <Response [200]>
# Added page 19 to database for wine type 4
# <Response [200]>
# Added page 20 to database for wine type 4
# <Response [200]>
# Added page 21 to database for wine type 4
# <Response [200]>
# Added page 22 to database for wine type 4
# <Response [200]>
# Added page 23 to database for wine type 4
# <Response [200]>
# Added page 24 to database for wine type 4
# <Response [200]>
# Added page 25 to database for wine type 4
# <Response [200]>
# Added page 26 to database for wine type 4
# <Response [200]>
# Added page 27 to database for wine type 4
# <Response [200]>
# Added page 28 to database for wine type 4
# <Response [200]>
# Added page 29 to database for wine type 4
# <Response [200]>
# Added page 30 to database for wine type 4
# <Response [200]>
# Added page 31 to database for wine type 4
# <Response [200]>
# Added page 32 to database for wine type 4
# <Response [200]>
# Added page 33 to database for wine type 4
# <Response [200]>
# Added page 34 to database for wine type 4
# <Response [200]>
# Added page 35 to database for wine type 4
# <Response [200]>
# Added page 36 to database for wine type 4
# <Response [200]>
# Added page 37 to database for wine type 4
# <Response [200]>
# Added page 38 to database for wine type 4
# <Response [200]>
# Added page 39 to database for wine type 4
# <Response [200]>
# Added page 40 to database for wine type 4
# <Response [200]>
# Added page 41 to database for wine type 4
# <Response [200]>
# Added page 42 to database for wine type 4
# <Response [200]>
# Added page 43 to database for wine type 4
# <Response [200]>
# Added page 44 to database for wine type 4
# <Response [200]>
# Added page 45 to database for wine type 4
# <Response [200]>
# Added page 46 to database for wine type 4
# <Response [200]>
# Added page 47 to database for wine type 4
# <Response [200]>
# Added page 48 to database for wine type 4
# <Response [200]>
# Added page 49 to database for wine type 4
# <Response [200]>
# Added page 50 to database for wine type 4
# <Response [200]>
# Added page 51 to database for wine type 4
# <Response [200]>
# Added page 52 to database for wine type 4
# <Response [200]>
# Added page 53 to database for wine type 4
# <Response [200]>
# Added page 54 to database for wine type 4
# <Response [200]>
# Added page 55 to database for wine type 4
# <Response [200]>
# Added page 56 to database for wine type 4
# <Response [200]>
# Added page 57 to database for wine type 4
# <Response [200]>
# Added page 58 to database for wine type 4
# <Response [200]>
# Added page 59 to database for wine type 4
# <Response [200]>
# Added page 60 to database for wine type 4
# <Response [200]>
# Added page 61 to database for wine type 4
# <Response [200]>
# Added page 62 to database for wine type 4
# <Response [200]>
# <Response [200]>
# Added page 1 to database for wine type 3
# <Response [200]>
# Added page 2 to database for wine type 3
# <Response [200]>
# Added page 3 to database for wine type 3
# <Response [200]>
# Added page 4 to database for wine type 3
# <Response [200]>
# Added page 5 to database for wine type 3
# <Response [200]>
# Added page 6 to database for wine type 3
# <Response [200]>
# Added page 7 to database for wine type 3
# <Response [200]>
# Added page 8 to database for wine type 3
# <Response [200]>
# Added page 9 to database for wine type 3
# <Response [200]>
# Added page 10 to database for wine type 3
# <Response [200]>
# Added page 11 to database for wine type 3
# <Response [200]>
# Added page 12 to database for wine type 3
# <Response [200]>
# Added page 13 to database for wine type 3
# <Response [200]>
# Added page 14 to database for wine type 3
# <Response [200]>
# Added page 15 to database for wine type 3
# <Response [200]>
# Added page 16 to database for wine type 3
# <Response [200]>
# Added page 17 to database for wine type 3
# <Response [200]>
# Added page 18 to database for wine type 3
# <Response [200]>
# Added page 19 to database for wine type 3
# <Response [200]>
# Added page 20 to database for wine type 3
# <Response [200]>
# Added page 21 to database for wine type 3
# <Response [200]>
# Added page 22 to database for wine type 3
# <Response [200]>
# Added page 23 to database for wine type 3
# <Response [200]>
# Added page 24 to database for wine type 3
# <Response [200]>
# Added page 25 to database for wine type 3
# <Response [200]>
# Added page 26 to database for wine type 3
# <Response [200]>
# Added page 27 to database for wine type 3
# <Response [200]>
# Added page 28 to database for wine type 3
# <Response [200]>
# Added page 29 to database for wine type 3
# <Response [200]>
# Added page 30 to database for wine type 3
# <Response [200]>
# Added page 31 to database for wine type 3
# <Response [200]>
# Added page 32 to database for wine type 3
# <Response [200]>
# Added page 33 to database for wine type 3
# <Response [200]>
# Added page 34 to database for wine type 3
# <Response [200]>
# Added page 35 to database for wine type 3
# <Response [200]>
# Added page 36 to database for wine type 3
# <Response [200]>
# Added page 37 to database for wine type 3
# <Response [200]>
# Added page 38 to database for wine type 3
# <Response [200]>
# Added page 39 to database for wine type 3
# <Response [200]>
# Added page 40 to database for wine type 3
# <Response [200]>
# Added page 41 to database for wine type 3
# <Response [200]>
# Added page 42 to database for wine type 3
# <Response [200]>
# Added page 43 to database for wine type 3
# <Response [200]>
# Added page 44 to database for wine type 3
# <Response [200]>
# Added page 45 to database for wine type 3
# <Response [200]>
# Added page 46 to database for wine type 3
# <Response [200]>
# Added page 47 to database for wine type 3
# <Response [200]>
# Added page 48 to database for wine type 3
# <Response [200]>
# Added page 49 to database for wine type 3
# <Response [200]>
# Added page 50 to database for wine type 3
# <Response [200]>
# Added page 51 to database for wine type 3
# <Response [200]>
# Added page 52 to database for wine type 3
# <Response [200]>
# Added page 53 to database for wine type 3
# <Response [200]>
# Added page 54 to database for wine type 3
# <Response [200]>
# Added page 55 to database for wine type 3
# <Response [200]>
# Added page 56 to database for wine type 3
# <Response [200]>
# Added page 57 to database for wine type 3
# <Response [200]>
# Added page 58 to database for wine type 3
# <Response [200]>
# Added page 59 to database for wine type 3
# <Response [200]>
# Added page 60 to database for wine type 3
# <Response [200]>
# Added page 61 to database for wine type 3
# <Response [200]>
# Added page 62 to database for wine type 3
# <Response [200]>
# Added page 63 to database for wine type 3
# <Response [200]>
# Added page 64 to database for wine type 3
# <Response [200]>
# Added page 65 to database for wine type 3
# <Response [200]>
# Added page 66 to database for wine type 3
# <Response [200]>
# Added page 67 to database for wine type 3
# <Response [200]>
# Added page 68 to database for wine type 3
# <Response [200]>
# Added page 69 to database for wine type 3
# <Response [200]>
# Added page 70 to database for wine type 3
# <Response [200]>
# Added page 71 to database for wine type 3
# <Response [200]>
# Added page 72 to database for wine type 3
# <Response [200]>
# Added page 73 to database for wine type 3
# <Response [200]>
# Added page 74 to database for wine type 3
# <Response [200]>
# Added page 75 to database for wine type 3
# <Response [200]>
# Added page 76 to database for wine type 3
# <Response [200]>
# Added page 77 to database for wine type 3
# <Response [200]>
# Added page 78 to database for wine type 3
# <Response [200]>
# Added page 79 to database for wine type 3
# <Response [200]>
# Added page 80 to database for wine type 3
# <Response [200]>
# Added page 81 to database for wine type 3
# <Response [200]>
# Added page 82 to database for wine type 3
# <Response [200]>
# Added page 83 to database for wine type 3
# <Response [200]>
# Added page 84 to database for wine type 3
# <Response [200]>
# Added page 85 to database for wine type 3
# <Response [200]>
# Added page 86 to database for wine type 3
# <Response [200]>
# Added page 87 to database for wine type 3
# <Response [200]>
# Added page 88 to database for wine type 3
# <Response [200]>
# Added page 89 to database for wine type 3
# <Response [200]>
# Added page 90 to database for wine type 3
# <Response [200]>
# Added page 91 to database for wine type 3
# <Response [200]>
# Added page 92 to database for wine type 3
# <Response [200]>
# Added page 93 to database for wine type 3
# <Response [200]>
# Added page 94 to database for wine type 3
# <Response [200]>
# Added page 95 to database for wine type 3
# <Response [200]>
# Added page 96 to database for wine type 3
# <Response [200]>
# Added page 97 to database for wine type 3
# <Response [200]>
# Added page 98 to database for wine type 3
# <Response [200]>
# Added page 99 to database for wine type 3
# <Response [200]>
# Added page 100 to database for wine type 3
# <Response [200]>
# Added page 101 to database for wine type 3
# <Response [200]>
# Added page 102 to database for wine type 3
# <Response [200]>
# Added page 103 to database for wine type 3
# <Response [200]>
# Added page 104 to database for wine type 3
# <Response [200]>
# Added page 105 to database for wine type 3
# <Response [200]>
# Added page 106 to database for wine type 3
# <Response [200]>
# Added page 107 to database for wine type 3
# <Response [200]>
# Added page 108 to database for wine type 3
# <Response [200]>
# Added page 109 to database for wine type 3
# <Response [200]>
# Added page 110 to database for wine type 3
# <Response [200]>
# Added page 111 to database for wine type 3
# <Response [200]>
# Added page 112 to database for wine type 3
# <Response [200]>
# Added page 113 to database for wine type 3
# <Response [200]>
# Added page 114 to database for wine type 3
# <Response [200]>
# Added page 115 to database for wine type 3
# <Response [200]>
# Added page 116 to database for wine type 3
# <Response [200]>
# Added page 117 to database for wine type 3
# <Response [200]>
# Added page 118 to database for wine type 3
# <Response [200]>
# Added page 119 to database for wine type 3
# <Response [200]>
# Added page 120 to database for wine type 3
# <Response [200]>
# Added page 121 to database for wine type 3
# <Response [200]>
# Added page 122 to database for wine type 3
# <Response [200]>
# Added page 123 to database for wine type 3
# <Response [200]>
# Added page 124 to database for wine type 3
# <Response [200]>
# Added page 125 to database for wine type 3
# <Response [200]>
# Added page 126 to database for wine type 3
# <Response [200]>
# Added page 127 to database for wine type 3
# <Response [200]>
# Added page 128 to database for wine type 3
# <Response [200]>
# Added page 129 to database for wine type 3
# <Response [200]>
# Added page 130 to database for wine type 3
# <Response [200]>
# Added page 131 to database for wine type 3
# <Response [200]>
# Added page 132 to database for wine type 3
# <Response [200]>

# %%
import pandas as pd

cnx = conn.connect(**aws_db_config)
cursor = cnx.cursor(buffered=True)
SQL_Query = pd.read_sql_query(
        '''select Distinct * FROM WineData ORDER BY Id''', cnx)
df = pd.DataFrame(SQL_Query)
df
# Out:
#              Id                                               Name   Price  \
# 0         12424  Pol Roger Brut Vintage Champagne (Extra Cuvée ...   59.99
# 1         18110        Vilmart & Cie Cuvée Creation Champagne 1998  170.00
# 2         19671  R&L Legras Cuvée St-Vincent Blanc de Blancs Br...  199.99
# 3         82144  Louis Roederer Cristal Rosé Brut Champagne (Mi...  509.99
# 4         83452  Louis Roederer Cristal Rosé Brut Champagne (Mi...  950.00
# ...         ...                                                ...     ...
# 8337  170082349                Damiani Wine Cellars Bollicine N.V.   16.00
# 8338  170098712                 Jaume Serra Bouquet Cava Rosé N.V.   15.99
# 8339  170262152                         Angels & Cowboys Rosé 2021   14.99
# 8340  170372901                      19 Crimes Martha's Chard 2020   11.76
# 8341  170407068        Oyster River Morphos Pétillant Naturel 2021   20.00
#
#       Rating  NumRatings  Type               StyleName  Year  Body  Acidity  \
# 0        4.3       20330     3        French Champagne  2006     3        3
# 1        4.5         118     3        French Champagne  1998     3        3
# 2        4.3         252     3        French Champagne  1996     3        3
# 3        4.6        5471     3        French Champagne  2002     3        3
# 4        4.6        5471     3        French Champagne  1999     3        3
# ...      ...         ...   ...                     ...   ...   ...      ...
# 8337     3.9          48     3                    NONE     0    -1       -1
# 8338     3.3          89     3            Spanish Cava     0     2        3
# 8339     3.9        2381     4        Californian Rosé  2021     3        2
# 8340     3.7         279     2  Californian Chardonnay  2020     4        3
# 8341     4.2         568     3                    NONE  2021    -1       -1
#
#       Vintage  Nat                          Region        Country  Size  \
# 0           0    0                       Champagne         France   750
# 1           0    0                       Champagne         France  1500
# 2           0    0  Champagne Grand Cru 'Chouilly'         France   750
# 3           0    0                       Champagne         France   750
# 4           0    0                       Champagne         France   750
# ...       ...  ...                             ...            ...   ...
# 8337        1    0                    Finger Lakes  United States   750
# 8338        1    0                            Cava          Spain   750
# 8339        0    0                   Sonoma County  United States   750
# 8340        0    0                      California  United States   750
# 8341        0    0                           Maine  United States   750
#
#                     Winery
# 0                Pol Roger
# 1            Vilmart & Cie
# 2               R&L Legras
# 3           Louis Roederer
# 4           Louis Roederer
# ...                    ...
# 8337  Damiani Wine Cellars
# 8338           Jaume Serra
# 8339      Angels & Cowboys
# 8340             19 Crimes
# 8341          Oyster River
#
# [8342 rows x 16 columns]

# %%
df.to_csv("WineData.csv")
